# %% [markdown]
# <a href="https://colab.research.google.com/github/gourim2523-arch/-case-study/blob/main/visualization_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #**import** **libraries**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=sns.load_dataset("planets")
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# ...

# %% [markdown]
# # **count plot**

# %%
sns.countplot(data=df, y="method"); plt.title("Planet Discovery Methods"); plt.show()

# %% [markdown]
# # **histogram**

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    data=df,
    x="orbital_period",
    bins=30,
    kde=True
)
plt.title("distribution of orbital period")
plt.xlabel("orbital period(days)")
plt.ylabel("number of planets")
plt.show()

# %% [markdown]
# # box **plot**

# %%
sns.boxplot(data=df, x="method", y="orbital_period"); plt.xticks(rotation=90); plt.show()

# %% [markdown]
# # **scatterplot**

# %%
sns.scatterplot(data=df, x="distance", y="mass"); plt.title("Distance vs Mass"); plt.show()

# %% [markdown]
# # bar **plot**

# %%
sns.barplot(data=df, x="method", y="mass"); plt.xticks(rotation=90); plt.show()

# %% [markdown]
# # line **plot**

# %%
sns.lineplot(data=df, x="year", y="mass"); plt.title("Year vs Mass"); plt.show()

# %% [markdown]
# # correlation **heatmap**

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm"); plt.show()

# %% [markdown]
# # pair **plot**

# %%
sns.pairplot(df[["orbital_period","mass","distance","year"]].dropna()); plt.show()

# %% [markdown]
# # KDE plot-**planet** mass

# %%
plt.figure(figsize=(7,5))

sns.kdeplot(
    data=df,
    x="mass",
    fill=True
)

plt.title("Density Distribution of Planet Mass")
plt.xlabel("Mass")

plt.show()

# %% [markdown]
# # violin **plot**

# %%
sns.violinplot(data=df, x="method", y="orbital_period"); plt.xticks(rotation=90); plt.show()

# %% [markdown]
# # swarm **plot**

# %%
plt.figure(figsize=(12,6))

sns.swarmplot(data=df, x="method", y="mass", size=2)

plt.xticks(rotation=90)
plt.title("Planet Mass by Discovery Method")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 17.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # strip **plot**

# %%
plt.figure(figsize=(12,6))

sns.stripplot(data=df, x="method", y="mass", jitter=True)

plt.xticks(rotation=90)
plt.title("Planet Mass by Discovery Method")
plt.show()
